# %%
from spire.pdf import PdfDocument
from IPython.display import Image, display

# %%
doc = PdfDocument()
doc.LoadFromFile("../data/pdf/LightRAG: Simple and Fast Retrieval-Augmented Generation.pdf")

images = []

for page in range(doc.Pages.Count):
    for idx, image in enumerate(doc.Pages[page].ImagesInfo, 1):
        print(f"page: {page} - {idx}")
        display(Image(image.Image.ToArray()))
        # image.Image.Save(f"{page}_{idx}.png")
# Out:
# page: 2 - 1
# page: 2 - 2
# page: 2 - 3
# page: 12 - 1
# page: 13 - 1
# page: 13 - 2
# page: 14 - 1
# page: 14 - 2
